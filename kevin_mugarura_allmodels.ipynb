# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# pd.option().display.max_columns=50
# sns.set(style= "dark grid", rc={'axes.facecolor': '#CAF1DE'})

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('heart_disease.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# #  LogisticRegression
#  This is a statistical method used for binary classification. the goal is to predict one or two out comes based on one or more variables

# %%
# Do a count of possible column targets
df.target.value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
#Mean for training data
df.groupby('target').mean()
# Out:
#               age       sex        cp    trestbps        chol       fbs  \
# target
# 0       56.569138  0.827655  0.482966  134.106212  251.292585  0.164329
# 1       52.408745  0.570342  1.378327  129.245247  240.979087  0.134981
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.456914  139.130261  0.549098  1.600200  1.166333  1.158317  2.539078
# 1       0.598859  158.585551  0.134981  0.569962  1.593156  0.370722  2.119772

# %%
# create a scatter plot for heart disease vs age and maximum heart rate vs age
plt.figure(figsize=(10, 5))
plt.scatter(x=df.age[df.target==1], y=df.thalach[df.target==1], c='red', label='Heart Disease')
plt.legend()
plt.xlabel('Age')
plt.ylabel('Maximum Heart Rate')
plt.title('Heart Disease vs Age and Maximum Heart Rate vs Age')
# Out:
# Text(0.5, 1.0, 'Heart Disease vs Age and Maximum Heart Rate vs Age')

# %%
plt.scatter(x=df.age[df.target==0], y=df.thalach[df.target==0], s=50, c='green', label='No Heart Disease')
plt.xlabel('Age')
plt.ylabel('Maximum Heart Rate')
plt.title('Heart Disease vs Age and Maximum Heart Rate vs Age')
# Out:
# Text(0.5, 1.0, 'Heart Disease vs Age and Maximum Heart Rate vs Age')

# %%
# Create Logistic Regression Model
y = df.target.values
x = df.drop(['target'], axis=1)

# %%
#Normalization
x = (x - np.min(x))/np.max(x) - np.min(x)
