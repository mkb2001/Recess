# %%
import seaborn as sn
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('UceResultsBySchool2011-2016.csv')
df
# Out:
#        YEAR      DISTRICT                                              SCHOOL  \
# 0      2011         WAKISO                                 GAYAZA HIGH SCHOOL
# 1      2011         MUKONO                                 NAMILYANGO COLLEGE
# 2      2011         MUKONO                             MT.ST.MARY'S,NAMAGUNGA
# 3      2011         WAKISO                        UGANDA MARTYRS SS,NAMUGONGO
# 4      2011  BUSHENYI MAIN                                    KITABI SEMINARY
# ...     ...            ...                                                ...
# 17634  2016          ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016          ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016          ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016          ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016          ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
# ...

# %%
df.shape
# Out:
# (17639, 48)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17639 entries, 0 to 17638
# Data columns (total 48 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   YEAR                17639 non-null  int64
#  1   DISTRICT            17639 non-null  object
#  2   SCHOOL              17638 non-null  object
#  3   TOTAL CANDIDATES    17368 non-null  float64
#  4   TOTAL DIV 1         12858 non-null  float64
#  5   % DIV 1             17639 non-null  float64
#  6   TOTAL DIV 2         16880 non-null  float64
#  7   % DIV 2             17639 non-null  float64
#  8   TOTAL DIV 3         17168 non-null  float64
#  9   % DIV 3             17639 non-null  float64
#  10  TOTAL DIV 4         16888 non-null  float64
#  11  % DIV 4             17639 non-null  float64
#  12  TOTAL DIV 7         6489 non-null   float64
#  13  % DIV 7             17639 non-null  float64
#  14  TOTAL DIV 9         13454 non-null  float64
# ...

# %%
df.head()
# Out:
#    YEAR      DISTRICT                        SCHOOL  TOTAL CANDIDATES  \
# 0  2011         WAKISO           GAYAZA HIGH SCHOOL             176.0
# 1  2011         MUKONO           NAMILYANGO COLLEGE             151.0
# 2  2011         MUKONO       MT.ST.MARY'S,NAMAGUNGA             153.0
# 3  2011         WAKISO  UGANDA MARTYRS SS,NAMUGONGO             222.0
# 4  2011  BUSHENYI MAIN              KITABI SEMINARY              73.0
#
#    TOTAL DIV 1  % DIV 1  TOTAL DIV 2  % DIV 2  TOTAL DIV 3  % DIV 3  ...  \
# 0        175.0     99.4          1.0      0.6          NaN      0.0  ...
# 1        150.0     99.3          NaN      0.0          NaN      0.0  ...
# 2        151.0     98.7          2.0      1.3          NaN      0.0  ...
# 3        216.0     97.3          6.0      2.7          NaN      0.0  ...
# 4         71.0     97.3          2.0      2.7          NaN      0.0  ...
#
#    MALE TOTAL DIV3  MALE % DIV3  MALE TOTAL DIV4  MALE % DIV4   \
# ...

# %%
df.tail()
# Out:
#        YEAR DISTRICT                                              SCHOOL  \
# 17634  2016     ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016     ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016     ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016     ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016     ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
#        TOTAL CANDIDATES  TOTAL DIV 1  % DIV 1  TOTAL DIV 2  % DIV 2  \
# 17634             148.0          0.0      0.0         12.0      8.1
# 17635              68.0          0.0      0.0          2.0      2.9
# 17636             128.0          0.0      0.0          4.0      3.1
# 17637              45.0          0.0      0.0          1.0      2.2
# 17638              50.0          0.0      0.0          1.0      2.0
#
#        TOTAL DIV 3  % DIV 3  ...  MALE TOTAL DIV3  MALE % DIV3  \
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# FEMALE TOTAL DIV7     12875
# TOTAL DIV 7           11150
# MALE TOTAL DIV7       10131
# FEMALE TOTAL DIV1      9114
# MALE TOTAL DIV1        7601
# MALE TOTAL X           7260
# MALE TOTAL DIV9        7120
# FEMALE TOTAL X         7043
# FEMALE TOTAL DIV9      5290
# TOTAL DIV 1            4781
# TOTAL X                4235
# TOTAL DIV 9            4185
# FEMALE TOTAL DIV2      3307
# MALE TOTAL DIV2        2397
# MALE TOTAL DIV4        1379
# MALE TOTAL DIV3        1240
# FEMALE TOTAL DIV3      1165
# FEMALE TOTAL DIV4       958
# TOTAL DIV 2             759
# TOTAL DIV 4             751
# TOTAL DIV 3             471
# TOTAL CANDIDATES        271
# MALE % DIV4             134
# MALE % DIV3             134
# MALE % DIV7             134
# MALE % DIV2             134
# MALE % DIV1             134
# MALE % DIV9             134
# MALE % X                134
# FEMALE % X               58
# FEMALE % DIV3            58
# FEMALE % DIV9            58
# FEMALE % DIV4            58
# ...

# %%
columns = df.columns.to_series().apply()

# %%
df.columns.str.replace('','_')

# %%
for isduplicate in df.duplocate()arrays:
    if isduplicate:
        print( 'duplicates identified and dropped')
        df.drop_duplicates(inplace=True)
        break
    else:
        pass
print('No duplicates')
df[df.duplicated]

# %%
na = df.isna().any()
na
# Out:
# YEAR                  False
# DISTRICT              False
# SCHOOL                 True
# TOTAL CANDIDATES       True
# TOTAL DIV 1            True
# % DIV 1               False
# TOTAL DIV 2            True
# % DIV 2               False
# TOTAL DIV 3            True
# % DIV 3               False
# TOTAL DIV 4            True
# % DIV 4               False
# TOTAL DIV 7            True
# % DIV 7               False
# TOTAL DIV 9            True
# % DIV 9               False
# TOTAL X                True
# % X                   False
# FEMALE CANDIDATES     False
# FEMALE TOTAL DIV1      True
# FEMALE % DIV1          True
# FEMALE TOTAL DIV2      True
# FEMALE % DIV2          True
# FEMALE TOTAL DIV3      True
# FEMALE % DIV3          True
# FEMALE TOTAL DIV4      True
# FEMALE % DIV4          True
# FEMALE TOTAL DIV7      True
# FEMALE % DIV7          True
# FEMALE TOTAL DIV9      True
# FEMALE % DIV9          True
# FEMALE TOTAL X         True
# FEMALE % X             True
# ...

# %%
#Chreck for the number of missing rows that are null
null_rows = df[df.isna().any(axis=1)]
before_computation = len(null_rows.axes[0])
print('No of rows that are null values :' + str(before_computation))
# Out:
# No of rows that are null values :14511

# %%
# Remove rows without school names
df.dropna(thresh=None, subset=['SCHOOL'], inplace=True)

# %%
# statistics
# correlation use method corr() calculates coefficient between all columns in the dataframe
# strong positive 1 
# weak correlation -1
#good and bad correlation i.e 

df = pd.DataFrame({
    'x':[1,2,3,4,5,6],
    'y':[7,8,9,10,11,12],
    'z':[13,14,55,15,16,16]}

)
correlation = df.corr()
print(correlation)
# Out:
#           x         y         z
# x  1.000000  1.000000 -0.061727
# y  1.000000  1.000000 -0.061727
# z -0.061727 -0.061727  1.000000
