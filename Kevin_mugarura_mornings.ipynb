# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np

# %%
#Read the dataset
pd.options.display.max_columns=50
sn.set(style="whitegrid", rc={"axes.facecolor":"#CAF1DE"})

# %%
df = pd.read_csv('bse_dataset4.csv')
df
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1                    NaN  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5                    NaN         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10                   NaN           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'gender', 'Age', 'emotion', 'YOB', 'CGPA',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? ', 'Duration',
#        'Pulse', 'Maxpulse', 'Calories'],
#       dtype='object')

# %%
df.shape
# Out:
# (169, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 15 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           168 non-null    object
#  1   gender                                              169 non-null    object
#  2   Age                                                 167 non-null    float64
#  3   emotion                                             168 non-null    object
#  4   YOB                                                 169 non-null    object
#  5   CGPA                                                169 non-null    object
#  6   Do you have a Girl Friend or BOY Friend             169 non-null    object
#  7   Do you have Depression?                             169 non-null    object
# ...

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Calories                                              5
# Age                                                   2
# Timestamp                                             1
# emotion                                               1
# gender                                                0
# YOB                                                   0
# CGPA                                                  0
# Do you have a Girl Friend or BOY Friend               0
# Do you have Depression?                               0
# Do you have Anxiety?                                  0
# Do you have Panic attack?                             0
# Did you have seek any specialist for a treatment?     0
# Duration                                              0
# Pulse                                                 0
# Maxpulse                                              0
# dtype: int64

# %% [markdown]
# # Drop Null Values

# %%
df_new = df.dropna(100,inplace=True)
df_new

# %%
#

# %%
for i in df.columns:
    if df[i].isnull().any():
        print(i, "....", df[i].isnull().sum()*100/df.shape[0], "%")
# Out:
# Timestamp .... 0.591715976331361 %
# Age .... 1.183431952662722 %
# emotion .... 0.591715976331361 %
# Calories .... 2.9585798816568047 %

# %% [markdown]
# # Calculate mean

# %%
mean = df['Calories'].mean()
df['Calories'].fillna( mean, inplace=True)

# %%
#Display dataframeall rows and columns
pd.set_option('dispaly.max_rows', None)
pd.set_option('dispaly.max_columns', None)

# %% [markdown]
# # Calculate Median

# %%
 median = df['Calories'].meadian()
df['Calories'].fillna(median, inplace=True)

# %% [markdown]
# # Calculate Mode on Age

# %%
mode = df['Age'].mode()
df['Age'].fillna(mode, inplace=True)
df
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
#Display dataframeall rows and columns
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Wrong Format

# %%
df
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# 13   05/07/2023 09:39:40           MALE  22.0                  fine
# ...

# %%
df['Timestamp'].fillna(value="05/07/2023 09:44:16", inplace=True)
df
# Out:
#                 Timestamp         gender   Age               emotion  \
# 0     05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/20323 09:44:16  Marabou stock  45.0                 Weird
# 2     05/07/2023 09:39:09        Female   20.0                 Happy
# 3     05/07/2023 09:39:12           Male  21.0                 Happy
# 4     05/07/2023 09:39:14         Female  21.0                 Happy
# 5    05/07/20323 09:44:16         Female  23.0                Happy
# 6     05/07/2023 09:39:21         female  21.0            irritated
# 7     05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8     05/07/2023 09:39:26           Male  22.0                   Sad
# 9     05/07/2023 09:39:27         Female  20.0                 happy
# 10   05/07/20323 09:44:16           Male  24.0                 Happy
# 11    05/07/2023 09:39:27         Female  20.0                 happy
# 12    05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'],errors='coerce')
df['Timestamp'] = df['Timestamp'].interpolate()

# %%
df['Timestamp'] = df['Timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
df
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    2023-05-07 09:38:39           Male  21.0               Content
# 1    2023-05-07 09:38:54  Marabou stock  45.0                 Weird
# 2    2023-05-07 09:39:09        Female   20.0                 Happy
# 3    2023-05-07 09:39:12           Male  21.0                 Happy
# 4    2023-05-07 09:39:14         Female  21.0                 Happy
# 5    2023-05-07 09:39:17         Female  23.0                Happy
# 6    2023-05-07 09:39:21         female  21.0            irritated
# 7    2023-05-07 09:39:23        Female   22.0  In a state of wonder
# 8    2023-05-07 09:39:26           Male  22.0                   Sad
# 9    2023-05-07 09:39:27         Female  20.0                 happy
# 10   2023-05-07 09:39:27           Male  24.0                 Happy
# 11   2023-05-07 09:39:27         Female  20.0                 happy
# 12   2023-05-07 09:39:38           Male  25.0                 Happy
# ...

# %%
for x in df.index:
    if df.loc[x, "gender"] !in ["female", "male"]:
